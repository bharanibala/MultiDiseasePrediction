# %%
#heart disease

# %%
import pickle as pk

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
data = pd.read_excel("Heart_Categ.xlsx")
X = data.iloc[:,0:13]  
Y = data.iloc[:,-1] 

features = SelectKBest(score_func=chi2, k=13)
fit = features.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScores1 = pd.concat([dfcolumns,dfscores],axis=1)
featureScores1.columns = ['Features','Score'] 
print(featureScores1.nlargest(13,'Score'))
pk.dump(fit,open('HC.pickle','wb'))
# Out:
#     Features       Score
# 9    oldpeak  279.607156
# 2         cp  217.823922
# 11        ca  210.625919
# 8      exang  130.470927
# 7    thalach  104.815590
# 10     slope   33.673948
# 1        sex   24.373650
# 12      thal   19.373465
# 0        age   14.204103
# 3   trestbps   13.498210
# 4       chol   11.076937
# 6    restecg    9.739343
# 5        fbs    1.477550

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(1, figsize=(10, 5))
plt.title("Feature importance")
plt.bar(featureScores1['Features'],featureScores1['Score'])
plt.xlabel('Features')
plt.ylabel('Scores')
plt.show()

# %%
from numpy import set_printoptions
from sklearn.feature_selection import f_classif

features = SelectKBest(score_func=f_classif, k=4)
fit = features.fit(X, Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores2 = pd.concat([dfcolumns,dfscores],axis=1)
featureScores2.columns = ['Features','Score']  
print(featureScores2.nlargest(13,'Score'))
# Out:
#     Features       Score
# 8      exang  242.883889
# 2         cp  238.558457
# 9    oldpeak  231.466363
# 7    thalach  224.386191
# 11        ca  174.877078
# 10     slope  138.679393
# 12      thal  131.802996
# 1        sex   86.689707
# 0        age   39.989890
# 3   trestbps   20.922916
# 6    restecg   18.838205
# 4       chol   16.320556
# 5        fbs    1.736352

# %%
plt.figure(1, figsize=(10, 5))
plt.title("Feature importance")
plt.bar(featureScores2['Features'],featureScores2['Score'])
plt.xlabel('Features')
plt.ylabel('Scores')
plt.show()

# %%
#Diabetes

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
data = pd.read_excel("Diab_Categ.xlsx")
X = data.iloc[:,0:9]  
Y = data.iloc[:,-1] 

features = SelectKBest(score_func=chi2, k=9)
fit = features.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score'] 
print(featureScores.nlargest(9,'Score'))
# Out:
#                    Features       Score
# 2                   Glucose  195.444168
# 8                       Age  164.047290
# 1               Pregnancies  144.222058
# 5                   Insulin  110.625585
# 7  DiabetesPedigreeFunction   56.000964
# 6                       BMI   38.564918
# 4             SkinThickness   16.935605
# 0                        ID   12.740413
# 3             BloodPressure    7.227850

# %%
plt.figure(1, figsize=(14, 5))
plt.title("Feature importance")
plt.bar(featureScores['Features'],featureScores['Score'])
plt.xlabel('Features')
plt.ylabel('Scores')
plt.show()

# %%
from numpy import set_printoptions
from sklearn.feature_selection import f_classif

features = SelectKBest(score_func=f_classif, k=9)
fit = features.fit(X, Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']  
print(featureScores.nlargest(9,'Score'))
# Out:
#                    Features       Score
# 2                   Glucose  540.989878
# 6                       BMI  168.699086
# 1               Pregnancies  118.243914
# 8                       Age  114.948716
# 7  DiabetesPedigreeFunction   43.219528
# 5                   Insulin   35.758664
# 4             SkinThickness   14.036285
# 3             BloodPressure   13.706431
# 0                        ID    0.038165

# %%
plt.figure(1, figsize=(14, 5))
plt.title("Feature importance")
plt.bar(featureScores['Features'],featureScores['Score'])
plt.xlabel('Features')
plt.ylabel('Scores')
plt.show()

# %%
#Kidney disease

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
data = pd.read_excel("Kid_Categ.xlsx")
X = data.iloc[:,1:25]  
Y = data.iloc[:,-1] 

features = SelectKBest(score_func=chi2, k=24)
fit = features.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score'] 
print(featureScores.nlargest(24,'Score'))
# Out:
#    Features       Score
# 3        al  214.240709
# 10       bu  125.992018
# 4        su   96.838710
# 18      htn   83.760657
# 2        sg   78.951757
# 19       dm   77.640056
# 14     hemo   55.442901
# 9       bgr   54.686645
# 22       pe   46.580645
# 21    appet   44.013500
# 6        pc   43.410687
# 15      pcv   43.383817
# 23      ane   33.619128
# 1        bp   29.106038
# 5       rbc   28.806452
# 17       rc   26.678521
# 7       pcc   22.617188
# 20      cad   20.838710
# 11       sc   20.225806
# 8        ba   13.483871
# 0       age    6.826540
# 13      pot    6.741935
# 16       wc    4.058674
# 12      sod    3.768871

# %%
plt.figure(1, figsize=(14, 5))
plt.title("Feature importance")
plt.bar(featureScores['Features'],featureScores['Score'])
plt.xlabel('Features')
plt.ylabel('Scores')
plt.show()

# %%
from numpy import set_printoptions
from sklearn.feature_selection import f_classif

features = SelectKBest(score_func=f_classif, k=24)
fit = features.fit(X, Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']  
print(featureScores.nlargest(24,'Score'))
# Out:
#    Features       Score
# 14     hemo  297.213696
# 2        sg  295.304513
# 15      pcv  251.861230
# 17       rc  211.079932
# 18      htn  196.979858
# 19       dm  166.706686
# 3        al  154.974961
# 9       bgr   95.664210
# 12      sod   87.044271
# 10       bu   85.372533
# 22       pe   66.826977
# 21    appet   63.935168
# 6        pc   61.575594
# 23      ane   43.672482
# 1        bp   42.529242
# 4        su   38.704590
# 5       rbc   35.364577
# 7       pcc   26.839899
# 20      cad   24.028785
# 0       age   19.335540
# 8        ba   14.722478
# 11       sc    8.448339
# 16       wc    6.457637
# 13      pot    1.219434

# %%
plt.figure(1, figsize=(14, 5))
plt.title("Feature importance")
plt.bar(featureScores['Features'],featureScores['Score'])
plt.xlabel('Features')
plt.ylabel('Scores')
plt.show()
